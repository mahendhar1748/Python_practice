# %%
# using Beutiful Soup

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

url = "https://webscraper.io/test-sites/e-commerce/allinone/computers/tablets"

# getting request
r = requests.get(url)
print(r)
soup = BeautifulSoup(r.text,"lxml")
# Out:
# <Response [200]>

# %%
#finding all the boxes
boxes = soup.find_all("div",class_ = "col-md-4 col-xl-4 col-lg-4")
print(boxes)
print(len(boxes))
'''
product_name = []
for i in names:
    #print(i.string)
    a=i.text
    product_name.append(a)
print(product_name)
print(len(product_name))
'''
# Out:
# [<div class="col-md-4 col-xl-4 col-lg-4">
# <div class="card thumbnail">
# <div class="product-wrapper card-body">
# <img alt="item" class="img-fluid card-img-top image img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="price float-end card-title pull-right">$69.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/10" title="Lenovo IdeaTab">Lenovo IdeaTab</a>
# </h4>
# <p class="description card-text">7" screen, Android</p>
# </div>
# <div class="ratings">
# <p class="review-count float-end">7 reviews</p>
# <p data-rating="3">
# <span class="ws-icon ws-icon-star"></span>
# <span class="ws-icon ws-icon-star"></span>
# <span class="ws-icon ws-icon-star"></span>
# </p>
# </div>
# </div>
# </div>
# </div>, <div class="col-md-4 col-xl-4 col-lg-4">
# <div class="card thumbnail">
# <div class="product-wrapper card-body">
# ...

# %%
#printing only galaxy tab information

box = soup.find_all("div",class_ = "col-md-4 col-xl-4 col-lg-4")[3]
#print(box)
#printing all the strings
for i in box:
    print(i.text)
    
#printing only name 
name = box.find("a").text
print(name)

#printing description
desc = box.find("p",class_ = "description").text
print(desc)
# Out:
# $97.99
#
# Galaxy Tab 3
#
# 7", 8GB, Wi-Fi, Android 4.2, White
#
#
# 2 reviews
#
#
#
#
#
#
#
#
#
# Galaxy Tab 3
# 7", 8GB, Wi-Fi, Android 4.2, White

# %%
#Nav bar

navbar = soup.find_all("ul",class_ = "nav flex-column",id = "side-menu")[0]

name = (soup.find("li",class_ = "activate"))
print(name.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 6
#       3 navbar = soup.find_all("ul",class_ = "nav flex-column",id = "side-menu")[0]
#       5 name = (soup.find("li",class_ = "activate"))
# ----> 6 print(name.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'
